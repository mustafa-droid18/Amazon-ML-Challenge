# %%
import pandas as pd
import numpy as np 
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from nltk.stem import WordNetLemmatizer
lm= WordNetLemmatizer()


#nltk.download('wordnet')

#nltk.download('punkt')

#nltk.download('stopwords')

# %%
df_train = pd.read_csv('dataset/train.csv')
df_train.head(10)
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
# 5     2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 6      413758                      Ungifted: My Life and Journey
# 7     2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# 8     2050239  PUMA Cali Sport Clean Women's Sneakers White L...
# 9     2998633  Hexwell Essential oil for Home Fragrance Oil A...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2249698 entries, 0 to 2249697
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PRODUCT_ID       int64
#  1   TITLE            object
#  2   BULLET_POINTS    object
#  3   DESCRIPTION      object
#  4   PRODUCT_TYPE_ID  int64
#  5   PRODUCT_LENGTH   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 103.0+ MB

# %%
df_train.count()
# Out:
# PRODUCT_ID         2249698
# TITLE              2249686
# BULLET_POINTS      1412334
# DESCRIPTION        1092317
# PRODUCT_TYPE_ID    2249698
# PRODUCT_LENGTH     2249698
# dtype: int64

# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
df_train=df_train.fillna(' ')

# %%
words = nltk.word_tokenize(df_train['TITLE'][1])
print (words)
# Out:
# ['Marks', '&', 'Spencer', 'Girls', "'", 'Pyjama', 'Sets', 'T86_2561C_Navy', 'Mix_9-10Y']

# %%
df= df_train.iloc[:5].copy()
df['TITLE']=df['TITLE'].apply(lambda x: nltk.word_tokenize(x) if isinstance(x, str) else x)
df['TITLE']=df['TITLE'].apply(lambda x: [word for word in x if word.isalnum()])
df['TITLE']=df['TITLE'].apply(lambda x: [word for word in x if word not in set(stopwords.words("english"))])
#df['TITLE']=df['TITLE'].apply(lambda x: [ps.stem(word) for word in x])
df['TITLE']=df['TITLE'].apply(lambda x: [lm.lemmatize(word) for word in x])
df
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  [ArtzFolio, Tulip, Flowers, Blackout, Curtain,...
# 1     2673191              [Marks, Spencer, Girls, Pyjama, Sets]
# 2     2765088  [PRIKNIK, Horn, Red, Electric, Air, Horn, Comp...
# 3     1594019  [ALISHAH, Women, Cotton, Ankle, Length, Leggin...
# 4      283658  [The, United, Empire, Loyalists, A, Chronicle,...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3  [Made By 95%cotton and 5% Lycra which gives yo...
# 4
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                                                1650
# 1                                                                2755
# 2  Specifications: Color: Red, Material: Aluminiu...             7537
# ...

# %%
columns = ['TITLE','BULLET_POINTS','DESCRIPTION']
for i in columns:
    df[i]=df[i].apply(lambda x: nltk.word_tokenize(x) if isinstance(x, str) else x)
    df[i]=df[i].apply(lambda x: [word for word in x if word.isalnum()])
    df[i]=df[i].apply(lambda x: [word for word in x if word not in set(stopwords.words("english"))])
    #df[i]=df[i].apply(lambda x: [ps.stem(word) for word in x])
    df[i]=df[i].apply(lambda x: [lm.lemmatize(word) for word in x])
    df[i]=df[i].apply(lambda x: [word.lower() for word in x]) 
df
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  [artzfolio, tulip, flowers, blackout, curtain,...
# 1     2673191              [marks, spencer, girls, pyjama, sets]
# 2     2765088  [priknik, horn, red, electric, air, horn, comp...
# 3     1594019  [alishah, women, cotton, ankle, length, leggin...
# 4      283658  [the, united, empire, loyalists, a, chronicle,...
#
#                                        BULLET_POINTS  \
# 0  [luxurious, appealing, beautiful, curtain, dec...
# 1  [harry, potter, hedwig, pyjamas, yrs, cotton, ...
# 2  [loud, dual, tone, trumpet, horn, compatible, ...
# 3  [made, by, 95, cotton, 5, lycra, give, 4, way,...
# 4                                                 []
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                                 []             1650
# 1                                                 []             2755
# ...

# %%
def displyafull(df, col):
    for i in range(5):
        print(i, '. ', df[col][i])

# %%
displyafull(df, 'TITLE')
print('-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
displyafull(df_train, 'TITLE')
print('=====================================================================================================================================================================================================')
displyafull(df, 'BULLET_POINTS')
print('-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
displyafull(df_train, 'BULLET_POINTS')
print('=====================================================================================================================================================================================================')
displyafull(df, 'DESCRIPTION')
print('-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
displyafull(df_train, 'DESCRIPTION')
print('=====================================================================================================================================================================================================')
# Out:
# 0 .  ['artzfolio', 'tulip', 'flowers', 'blackout', 'curtain', 'door', 'window', 'room', 'eyelets', 'tie', 'back', 'canvas', 'fabric', 'width', '54inch', 'height', '5', 'foot', '60', 'inch', 'set', '2', 'pcs']
# 1 .  ['marks', 'spencer', 'girls', 'pyjama', 'sets']
# 2 .  ['priknik', 'horn', 'red', 'electric', 'air', 'horn', 'compressor', 'interior', 'dual', 'tone', 'trumpet', 'loud', 'compatible', 'sx4']
# 3 .  ['alishah', 'women', 'cotton', 'ankle', 'length', 'leggings', 'combo', '2', 'plus', '12']
# 4 .  ['the', 'united', 'empire', 'loyalists', 'a', 'chronicle', 'great', 'migration']
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0 .  ArtzFolio Tulip Flowers Blackout Curtain for Door, Window & Room | Eyelets & Tie Back | Canvas Fabric | Width 4.5feet (54inch) Height 5 feet (60 inch); Set of 2 PCS
# ...

# %%
columns = ['TITLE','BULLET_POINTS','DESCRIPTION']
df= df_train.copy()
for i in columns:
    df[i]=df[i].apply(lambda x: nltk.word_tokenize(x) if isinstance(x, str) else x)
    df[i]=df[i].apply(lambda x: [word for word in x if word.isalnum()])
    df[i]=df[i].apply(lambda x: [word for word in x if word not in set(stopwords.words("english"))])
    #df[i]=df[i].apply(lambda x: [ps.stem(word) for word in x])
    df[i]=df[i].apply(lambda x: [lm.lemmatize(word) for word in x])
    df[i]=df[i].apply(lambda x: [word.lower() for word in x]) 
df
