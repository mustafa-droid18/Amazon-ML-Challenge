# %%
import pandas as pd
import numpy as np 
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from nltk.stem import WordNetLemmatizer
lm= WordNetLemmatizer()

# %%
df_train = pd.read_csv('dataset/train.csv')
df_train.head(10)
df_train=df_train.fillna(' ')

# %%
def Batch(upper,lower=0):
    df=df_train.iloc[lower:upper].copy()
    columns = ['TITLE','BULLET_POINTS','DESCRIPTION']
    for i in columns:
        df[i]=df[i].apply(lambda x: nltk.word_tokenize(x) if isinstance(x, str) else x)
        df[i]=df[i].apply(lambda x: [word for word in x if word.isalnum()])
        df[i]=df[i].apply(lambda x: [word for word in x if word not in set(stopwords.words("english"))])
        #df[i]=df[i].apply(lambda x: [ps.stem(word) for word in x])
        df[i]=df[i].apply(lambda x: [lm.lemmatize(word) for word in x])
        df[i]=df[i].apply(lambda x: [word.lower() for word in x])
    df.to_csv('new_dataset/dataset_{}_{}.csv'.format(lower,upper), index=False) 
    return df

# %%
Batch(50000)
# Out:
#        PRODUCT_ID                                              TITLE  \
# 0         1925202  [artzfolio, tulip, flowers, blackout, curtain,...
# 1         2673191              [marks, spencer, girls, pyjama, sets]
# 2         2765088  [priknik, horn, red, electric, air, horn, comp...
# 3         1594019  [alishah, women, cotton, ankle, length, leggin...
# 4          283658  [the, united, empire, loyalists, a, chronicle,...
# ...           ...                                                ...
# 49995      173286  [cowboys, buckaroos, trade, secrets, of, a, no...
# 49996       37801  [freshwater, ecosystems, revitalizing, educati...
# 49997     2639035  [bangaru, kamakshi, tanjore, thanjavur, amman,...
# 49998     1459482  [fraas, lightweight, oversize, plaid, scarf, w...
# 49999     2554038  [primefair, women, microfiber, saree, shapewea...
#
#                                            BULLET_POINTS  \
# 0      [luxurious, appealing, beautiful, curtain, dec...
# 1      [harry, potter, hedwig, pyjamas, yrs, cotton, ...
# 2      [loud, dual, tone, trumpet, horn, compatible, ...
# 3      [made, by, 95, cotton, 5, lycra, give, 4, way,...
# 4                                                     []
# ...                                                  ...
# 49995                                                 []
# 49996                                                 []
# 49997  [also, available, online, store, beautiful, ba...
# 49998  [stylisch, der, zeitlose, passt, perfekt, im, ...
# 49999  [shaping, saree, shapewear, petticoat, stomach...
#
#                                              DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                                     []             1650
# 1                                                     []             2755
# 2      [specifications, color, red, material, alumini...             7537
# 3      [aishah, women, lycra, cotton, ankel, leggings...             2996
# 4                                                     []             6112
# ...                                                  ...              ...
# 49995                                                 []              178
# 49996                                                 []            12024
# 49997  [painting, beautifully, designed, perfectly, f...             5506
# 49998  [fraas, plaid, created, upper, franconia, one,...             2968
# 49999  [primefair, a, saree, petticoat, much, hold, d...             2917
#
#        PRODUCT_LENGTH
# 0         2125.980000
# 1          393.700000
# 2          748.031495
# 3          787.401574
# 4          598.424000
# ...               ...
# 49995      816.000000
# 49996      626.000000
# 49997     1200.000000
# 49998     7874.015740
# 49999      590.551180
#
# [50000 rows x 6 columns]
